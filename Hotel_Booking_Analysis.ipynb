# %% [markdown]
# # **Project Name**    - Hotel Booking Analysis

# %% [markdown]
# ###### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# #####  **Member**  - Meet Mishra

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the numb. Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# This data set contains booking information for a city hotel and a resort hotel, and includes information such highest number of bookings in hotels, and include information such as which hotel has generated more revenue,Trenfd of ADR Year wise, hotel cancellation rate,average stay of customers,top 10 countries by bookings,booking done by distribution channel,booking trend by month wise,most preferred meal.All unnecessary information has been removed from the data.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The project contains the real world data record of hotel bookings of a city and a resort hotel containing details like bookings, cancellations, guest details etc. from 2015 to 2017. In this project we are going to analyze Hotel Booking Data in order to find out valuable insights and give suggestions to increase revenue of hotels.
# -  Which hotel has most number of bookings?
# -  Which hotel generated more revenue?
# -  Trend of ADR Year wise?
# -  Which hotel has more cancellation rate?
# -  What is the average stay of customer?
# -  Number of booking for top 10 countries?
# -  Number of booking by which distribution channel?
# -  What was the booking trend month wise?
# -  Which meal is mostly in fashion?
# -  Preferred medium used by customer for booking in hotels?
# -  Checking correlation between each and every features?
# -  Checking correlation between some columns?

# %% [markdown]
# Define Your Business Objective?

# %% [markdown]
# We are provided with a hotel bookings dataset.
#
# Our main objective is to perform EDA on the given dataset and draw useful conclusions about general trends in hotel bookings and how factors governing hotel bookings interact with each other.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Mounting Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
path = r'/content/drive/MyDrive/Colab Notebooks/almabetterproject/exploratory data analysis/hotel booking analysis/Hotel Bookings.csv'
hotel_df = pd.read_csv(path, encoding='unicode_escape')

# Creating a copy of our DataFrame to keep original dataFrame untouched
df = hotel_df.copy()

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f'Number Of Rows: {df.shape[0]}')
print(f'Number Of Columns: {df.shape[1]}')
# Out:
# Number Of Rows: 119390
# Number Of Columns: 32

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print(f'Number Of Duplicate Rows: {df.duplicated().sum()}')
# Out:
# Number Of Duplicate Rows: 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing value
sns.set(rc={'figure.figsize': (14,5)})
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset contains 119,390 observations for a City Hotel and a Resort Hotel. Each observation represents a hotel booking between the 1st of July 2015 and 31st of August 2017, including bookings that effectively arrived and bookings that were canceled . The dataset contains 32 columns with information such as hotel type, booking status, lead time, arrival date, number of stays, number of guests, meal type, country of origin, market segment, distribution channel, deposit type, agent ID, company ID, days in waiting list, customer type, average daily rate (ADR), required car parking spaces, total number of special requests made by the guest and more .
#
# - Now we can also see that columns like children, country, agent and company have null values.
# - Among those columns company and agent columns have huge numbers of null values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# Type of different features for each column/feature (only 'object' Datatype)
for col in df.describe(include=object).columns:
  if col == 'reservation_status_date':
    continue
  print(col)
  print(df[col].unique())
  print('-'*30)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# - `hotel`: The type of hotel (Resort or City).
# - `is_canceled`: Value indicating if the booking was canceled (1) or not (0).
# - `lead_time`: Number of days that elapsed between the entering date of the booking into the PMS and the arrival date.
# - `arrival_date_year`: Year of arrival date.
# - `arrival_date_month`: Month of arrival date.
# - `arrival_date_week_number`: Week number of year for arrival date.
# - `arrival_date_day_of_month`: Day of arrival date.
# - `stays_in_weekend_nights`: Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel.
# - `stays_in_week_nights`: Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel.
# - `adults`: Number of adults.
# - `children`: Number of children.
# - `babies`: Number of babies.
# - `meal`: Type of meal booked. Categories are presented in standard hospitality meal packages: Undefined/SC – no meal package; BB – Bed & Breakfast; HB – Half board (breakfast and one other meal – usually dinner); FB – Full board (breakfast, lunch and dinner).
# - `country`: Country of origin.
# - `market_segment`: Market segment designation. In categories such as groups, corporate, etc. .
# - `distribution_channel`: Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators” .
# - `is_repeated_guest`: Value indicating if the booking name was from a repeated guest (1) or not (0).
# - `previous_cancellations`: Number of previous bookings that were cancelled by the customer prior to the current booking.
# - `previous_bookings_not_canceled`: Number of previous bookings not cancelled by the customer prior to the current booking.
# - `reserved_room_type`: Code of room type reserved. Code is presented instead of designation for anonymity reasons .
# - `assigned_room_type`: Code for the type of room assigned to the booking. Sometimes the assigned room type differs from reserved room type due to hotel operation reasons (e.g. overbooking) or by customer request. Code is presented instead of designation for anonymity reasons .
# - `booking_changes`: Number of changes/amendments made to the booking from the moment it was entered on the PMS until check-in or cancellation.
# - `deposit_type`: Indication on if the customer made a deposit to guarantee the booking. This variable can assume three categories: No Deposit – no deposit was made; Non Refund – a deposit was made in the value equivalent to the total stay cost; Refundable – a deposit was made with a value less than or equal to 100% of the total cost of stay .
# - `agent`: ID of travel agency that made the booking.
# - `company`: ID of company/entity that made the booking or responsible for paying the booking. ID is presented instead of designation for anonymity reasons .
# - `days_in_waiting_list`: Number of days the booking was in waiting list before it was confirmed to the customer.
# - `customer_type`: Type of booking, assuming one of four categories: Contract - when the booking has an allotment or other type of contract associated to it; Group – when the booking is associated to a group; Transient – when the booking is not part of a group or contract, and is not associated to other transient booking; Transient-party – when transient but with at least one other transient booking with same characteristics (e.g. same check-in and check-out date) .
# - `adr`: Average Daily Rate as defined by dividing sum of revenue / total number of stays.
# - `required_car_parking_spaces`: Number of car parking spaces required by customer.
# - `total_of_special_requests`: Number of special requests made by customer (e.g. twin bed or high floor).
# - `reservation_status`: Reservation last status, assuming one of three categories: Canceled – booking was canceled by guest; Check-Out – guest has checked in but already departed; No-Show – guest did not check-in and inform hotel about his/her decision .
# - `reservation_status_date`: Date at which last status was set.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# **Data Cleaning**

# %%
# Dropping company column.
df.drop("company", axis = 1, inplace = True)

# %%
# Dropping rows of null value of children and country column.
df.dropna(subset=["country", "children"], axis = 0, inplace = True)

# %%
# Filling null values of column agent with string 'Unknown'.
df.fillna({'agent': "Unknown"}, inplace = True)

# %%
# checking null values of all column
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %% [markdown]
# **Data Manipulation**

# %%
#checking data types
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
# changing data type of 'children' and 'adr' into integer.
# changing data type of 'reservation_status_date' column into datetime.

df[["children", "adr"]] = df[["children", "adr"]].astype(int)
df["reservation_status_date"] = pd.to_datetime(df["reservation_status_date"])

# %%
df.dtypes
# Out:
# hotel                                     object
# is_canceled                                int64
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                        object
# arrival_date_week_number                   int64
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                   int64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **Data cleaning**
# -  As company column have so many null values and it's of no use, also not related to our analysis so we dropped that column from our dataset.
# -  Dropping all rows consisting null values of column children and country.
# -  we have filled null values of column agent with string "Unknown"
#
# **Data manipulation**
# -  first we checked all the data type of columns given.
# -  Then we changed data type of children and adr into integer data type after that
# -  we changed data type of reservation_status_date into to_datetime data type

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# # Which hotel has most number of bookings?

# %%
ax = sns.countplot(data=df,x='hotel')
for bar in ax.containers:
  ax.bar_label(bar)
plt.xlabel("Hotel Type")
plt.ylabel("Count")
plt.title("Number Of Booking Vs Hotel Type")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We opted for a count plot as our visualization choice because it allows us to effectively depict the frequency of observations within categorical data, aligning with our goal of visualizing counts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Insights**
# -  Based on the chart generated from the dataset, the observation is evident: City Hotel has a higher number of bookings compared to Resort Hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above chart we can see booking has happened most by city hotel.It will guide Stakeholders to invest their money.

# %% [markdown]
# # Which hotel generated more revenue?

# %%
# Creating a new column name- total_room_sold to calculate revenue and making revenue as another column.
df['total_room_sold']= df['stays_in_weekend_nights']+ df['stays_in_week_nights']
df['revenue']= df['adr']* df['total_room_sold']
revenue_by_hotel = df.groupby('hotel',as_index=False)['revenue'].sum()

# %%
sns.barplot(data=revenue_by_hotel,x='hotel',y='revenue')
plt.title("Revenue by Hotel")
plt.xlabel("Hotel Type")
plt.ylabel("Total Revenue")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We have two categorical data that's why we preferred bar chart

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart it is clear that `City Hotel` generated more revenue

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As Resort Hotel generated less revenue so it need more facilities

# %% [markdown]
# #Trend of ADR Year wise?

# %%
adr_by_year = df.groupby("arrival_date_year",as_index=False)["adr"].mean().sort_values(by='adr',ascending =False)
adr_by_year
adr_by_year.plot(kind='line',x='arrival_date_year',y='adr')
plt.xlabel("Year")
plt.ylabel("Average daily rate")
plt.title("Year vs ADR")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# As we want to find the trend so we have used the line chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart we can see that adr is increasing year by year.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,It will help business to determine the suitable price.

# %% [markdown]
# #Which hotel has more cancellation rate?

# %%
# Creating new variable df_canceled with only canceled data.
df_canceled = df[df['is_canceled']==1]
canceled_data = df_canceled.groupby(by='hotel',as_index=False).is_canceled.count()

# %%
sns.barplot(data=canceled_data,x='hotel',y='is_canceled')
plt.title('Number of Cancellation in each hotel')
plt.xlabel('Hotel Type')
plt.ylabel('Number of Cancellation')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose bar chart because it enable us to compare numerical values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From previous booking we can see that city hotel has more booking but with this chart we can see it has maximum number of cancellation also.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above chart it can guide stake holders about their investment.
# This negative growth of city hotel going in losses so to prevent that we can look for the factors which leads to loss.

# %% [markdown]
# # What is the average stay of customer?

# %%
# Creating a new column name- total_stay.
df['total_stay'] = df['stays_in_week_nights'] + df['stays_in_weekend_nights']
avg_stay_by_customer_type = df.groupby(by='customer_type', as_index=False)['total_stay'].mean().round(2).sort_values(by='total_stay' , ascending=False)

# %%
sns.barplot(data=avg_stay_by_customer_type, x='customer_type', y='total_stay', palette='dark')
plt.title('Average Stay of Customer Type', fontsize = 30)
plt.xlabel('Customer Type', fontsize=15)
plt.ylabel('Average Length Of Stay', fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It shows variation in categories that's why we used bar charts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart it's clear that contract basis customer stays more than other type of customer.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can target contract based customer more and can provide more discounts to  generate more visits in upcoming future.
#
#
# For others customer type we can provide more discounts so they will chose that particular hotel more.

# %% [markdown]
# # Number of booking for top  10 countries?

# %%
# Creating a new variable name-booking_by_country.
booking_by_country= df.groupby(by='country',as_index = False)['hotel'].count().sort_values(by ='hotel',ascending=False).head(10)

# %%
ax = sns.barplot(data=booking_by_country, x='country', y='hotel', palette='dark')
for bar in ax.containers:
  ax.bar_label(bar)
plt.title('Top 10 countries by number of hotel bookings', fontsize=20)
plt.xlabel('Country', fontsize=15)
plt.ylabel('Number of Booking', fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because we want to show the frequency of booking among top 10 countries that's why we used bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It's clearly visible customers from portugal are more likely to book in our hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This shows our hotels have great attributes for which all these countries likely to book our hotel.
#
#
# We can look for developement and suitable price in our hotels for other countries to likely choose our hotel more.

# %% [markdown]
# # Number of booking by which distribution channel?

# %%
# Creating a new variable name- booking_by_channel.
booking_by_channel = df.groupby(by='distribution_channel')['hotel'].count().reset_index(name='bookings').sort_values(by='bookings',ascending=False)

# %%
ax = sns.barplot(data=booking_by_channel,x='distribution_channel',y='bookings')
ax.set_xlabel('distribution_channel')
ax.set_ylabel('bookings')
ax.set_title('Booking done by distribution channel')
for bar in ax.containers:
  ax.bar_label(bar)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar graphs are used to measure the changes over a period of time that's why we went for bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart we can see booking are mostly done through TA/TO channel than Direct or Corporate channels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We should focus more on TA/TO channel like what new we can add in it so it could bring more of bookings.
#
# We should look for reasons behind this minimum growth of other channels and likewisely should look for options which could repair it.

# %% [markdown]
# # What was the booking trend month wise?

# %%
# making month as categorical variable
categories = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df['arrival_month'] = pd.Categorical(df['arrival_date_month'], categories=categories, ordered=True)
booking_by_month = df.groupby(by='arrival_month', as_index=False)['hotel'].count()

# %%
booking_by_month.plot('arrival_month', 'hotel')
plt.title('Booking Trend By Month', fontsize=20)
plt.xlabel('Month', fontsize=15)
plt.ylabel('Number Of Bookings', fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We decided to go with line chart because line charts supports monitoring behaviour in a set of data.They also help in highlighting differences and correlations within your data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above chart we can see bookings are higher from month July to September.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It'll give an idea of what season brings more revenue and on what season we should look for solutions to get more revenue from it.

# %% [markdown]
# #### Which meal is mostly in fashion?

# %%
# Creating a new variable name- meal_count.
meal_count =  df.groupby('meal')['meal'].count().sort_values(ascending=False)

# %%
plt.bar(meal_count.index,meal_count.values)
plt.title("Meal Demand")
plt.xlabel("Meal category")
plt.ylabel("No of orders")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# When the changes are larger a Bar graph is the best option to represent the data that's why we used bar graphs.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above chart we can clearly sense BB food is mostly in demand.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# To increase production of more side meals with BB food so we can get more revenue from food line.
#
#
# While we should look for other options or varieties in HB and SC food so it could also get us more revenue.

# %% [markdown]
# # Percentage of booking Daywise?

# %%
# Creating a new column name-arrival_date
df['arrival_date'] = pd.to_datetime(df['arrival_date_year'].astype(str)+'/'+df['arrival_date_month']+'/'+df['arrival_date_day_of_month'].astype(str))
bookings_by_day = df['arrival_date'].dt.day_name().value_counts()

# %%
ax = plt.pie(bookings_by_day, labels=bookings_by_day.index, autopct='%1.1f%%', radius=1, explode=[0.1,0,0,0,0,0,0], wedgeprops=dict(width=0.7))
plt.axis('equal')
plt.title('Hotel Bookings By Day Of The Week', fontsize=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We use pie chart  because it helps organize and show data as a percentage of a whole.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Maximum booking done on Friday,Thursday,Monday and Saturday respectively.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It shows that weekdays and weekend both gives us revenue.

# %% [markdown]
# # Checking correlation between each and every features?

# %%
sns.set(rc={"figure.figsize":(30,20)})
ax = sns.heatmap(df.corr(),annot = True,cmap='coolwarm')
plt.show()
# Out:
# <ipython-input-48-696d107ae94b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ax = sns.heatmap(df.corr(),annot = True,cmap='coolwarm')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To know the relations between each and every feature we used heatmap.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that how some columns correlate and create hues of red and darker blue like revenue and total_room_sold,total_stay and revenue and etc.

# %% [markdown]
# # Checking correlation between some columns?

# %%
sns.set({"figure.figsize":(30,20)})
sns.pairplot(data=df[['is_canceled','adr','lead_time', 'days_in_waiting_list']])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We used pair plot because it helps us understand large amount of data in a single figure.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above chart we can see what factors are dependent and independent to each other like days_in_waiting_list and lead_time have a positive correlation.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# As Resort Hotel generated less revenue so it need more facilities and we need to decide some suitable prices for buisness to outgrow.We can target contract based customer of City hotel more and can provide more discounts to generate more visits in upcoming future.For others customer type we can provide more discounts so they will chose City and Resort hotel more.This shows our hotels have great attributes for which all these countries likely to book our hotel.We can look for developement and suitable price in our hotels for other countries to likely choose our hotel more.We should focus more on TA/TO channel like what new we can add in it so it could bring more of bookings.We should look for reasons behind this minimum growth of other channels and likewisely should look for options which could repair it.We should focus more on seasonal sales and on off season we should look for solutions to get more revenue from it.To gain more revenue we need to increase production of more side meals with BB food so we can get more revenue from food line,while we should look for other options or varieties in HB and SC food so it could also bring more revenue.We can see both weekend and weekdays bring us revenue.While we should inspect other channels and shoud work on services provided by them.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# -  City Hotel has a higher number of bookings compared to Resort Hotel.
# -  City Hotel generated more revenue
# -  ADR[Average Daily Rate] is increasing year by year.
# -  We can see that city hotel has more booking but we can also see it has maximum number of cancellation also.
# -  It's clear that contract basis customer stays more than other type of customer.
# -  It's clearly visible customers from portugal are more likely to book in our hotels
# -  We can see booking are mostly done through TA/TO channel than Direct or Corporate channels.
# -  We can see bookings are higher from month July to September.
# -  We can clearly sense BB food is mostly in demand.
# -  Maximum booking done on Friday,Thursday,Monday and Saturday respectively.
# -  We can see that how some columns correlate and create hues of red and darker blue like revenue and total_room_sold,total_stay and revenue and etc.
# -  We can see what factors are dependent and independent to each other like days_in_waiting_list and lead_time have a correlation.
